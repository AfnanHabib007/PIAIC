# %%
5 + (6 / 4) * (2 % 5) + (6 / 2) + (5**2) * (3 + 5) + (6 / 4) * 2 - 5 + (6 / 2) %  (5**2) * 3 

#5 + (1.5) * (2) +       (3)    + (25) *      (8)  +   (1.5) *  2 - 5 + (3)   %   (25)   * 3
#5 + (3) + 3 + 200 + 3 - 5 +  3 * 3
#5 +3 + 3 +200+3-5+9
#233 - 5
#218
# Out:
# 218.0

# %%
string = "afnan\thaBiB"
# str.capitalize

print(string.capitalize())
print(string.casefold())
print(string.count("a",0,len(string)))
print(string.center(99,'!'))
print(string.encode(encoding='UTF-16',errors='strict'))
print(string.endswith("haBiB",8))
print(string.expandtabs(tabsize = 50))
print(string.find("haBiB",5))
name = "Hello, My name is {}"
name.format(string)
dictionary = {'name' : "Afnan",
             'fname' : "Habib",}
print('{name} {fname}'.format_map(dictionary))
print(string.index("haBiB",5))
print(string.isalnum())
print(string.isalpha())
print(string.isascii())
print(string.isdecimal())
print(string.isdigit())
print(string.isidentifier())
print(string.islower())
print(string.isnumeric())
print("afnan habib".isprintable())
print("   ".isspace())
print("Afnan Habib".istitle())
print("AFNAN HABIB".isupper())
print(" ".join(("Afnan", "Habib")))
print(string.ljust(50,'!'))
print("AFNAN HABIB".lower())
print("888888afnanhabib".lstrip('8'))
#maketrans
intab = 'aeiou'
outtab = '12345'
print(string.maketrans("12345","abcde")) #?.?
#print(string.mro())
print("I can eat Bananas everyday".partition("Bananas"))
print("mansehra mansehra mansehra mansehra".replace("mansehra","Abbotabad", 2))
print(string.rfind("ha",0,len(string)))
# Out:
# Afnan	habib
# afnan	habib
# 3
# !!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!afnan	haBiB!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!
# b'\xff\xfea\x00f\x00n\x00a\x00n\x00\t\x00h\x00a\x00B\x00i\x00B\x00'
# False
# afnan                                             haBiB
# 6
# Afnan Habib
# 6
# False
# False
# True
# False
# False
# False
# False
# False
# True
# True
# True
# True
# Afnan Habib
# afnan	haBiB!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!
# afnan habib
# afnanhabib
# {49: 97, 50: 98, 51: 99, 52: 100, 53: 101}
# ('I can eat ', 'Bananas', ' everyday')
# Abbotabad Abbotabad mansehra mansehra
# 6

# %%
#str.capitalize
#str.casefold
#str.center
#str.count
#str.encode
#str.endswith
#str.expandtabs
#str.find
#str.format
#str.format_map
#str.index
#str.isalnum
#str.isalpha
#str.isascii
#str.isdecimal
#str.isdigit
#str.isidentifier
#str.islower
#str.isnumeric
#str.isprintable
#str.isspace
#str.istitle
#str.isupper
#str.join
#str.ljust
#str.lower
#str.lstrip
#str.maketrans    ?.?
#str.mro          ?.?
#str.partition
#str.replace
#str.rfind
str.rindex
str.rjust
str.rpartition
str.rsplit
str.rstrip
str.split
str.splitlines
str.startswith
str.strip
str.swapcase
str.title
str.translate
str.upper
str.zfill
